# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.3/887.3 kB 20.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from IPython.display import display, Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.5/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}
# !yolo task=segment mode=train model=yolov8s-seg.pt  data=/content/drive/MyDrive/Colab_Notebooks/AI_project/datasetyolo/data.yaml epochs=10 imgsz=640
# Out:
# /content
# ...
# 100% 22.8M/22.8M [00:00<00:00, 41.9MB/s]
# New https://pypi.org/project/ultralytics/8.3.36 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/segment/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %%
# %cd {HOME}

# !yolo task=segment mode=val model={HOME}/runs/segment/train/weights/best.pt data=/content/drive/MyDrive/Colab_Notebooks/AI_project/datasetyolo/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11,780,761 parameters, 0 gradients, 42.4 GFLOPs
# val: Scanning /content/drive/MyDrive/Colab_Notebooks/AI_project/datasetyolo/valid/labels.cache... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.05it/s]
#                    all          4         37      0.719      0.368      0.407      0.356      0.724      0.185      0.202     0.0476
#               Building          3         18      0.238      0.105     0.0952     0.0406      0.356     0.0556     0.0923     0.0132
#             Main_image          4          4      0.919          1      0.995      0.969      0.815        0.5      0.513      0.128
# ...

# %%
# %cd {HOME}
# !yolo task=segment mode=predict model={HOME}/runs/segment/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/Colab_Notebooks/AI_project/datasetyolo/test/images save=true
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11,780,761 parameters, 0 gradients, 42.4 GFLOPs
#
# image 1/3 /content/drive/MyDrive/Colab_Notebooks/AI_project/datasetyolo/test/images/664d4f1b49dd860001fae0ee_png.rf.e1ed8d31993fdef516db0f5e44808081.jpg: 640x640 27 Buildings, 2 Main_images, 3 Roads, 20.9ms
# image 2/3 /content/drive/MyDrive/Colab_Notebooks/AI_project/datasetyolo/test/images/672a7910112bc40001f7711b_png.rf.b8eb0e6e3c044654bb3ca6bda35ed518.jpg: 640x640 3 Buildings, 1 Main_image, 20.9ms
# image 3/3 /content/drive/MyDrive/Colab_Notebooks/AI_project/datasetyolo/test/images/672ebf3404bd070001991c93_png.rf.cccf3b596321ce1cdc30242996f51264.jpg: 640x640 2 Buildings, 1 Main_image, 20.9ms
# Speed: 2.2ms preprocess, 20.9ms inference, 211.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/segment/predict2/*.jpg')[:3]:
      display(Image(filename=image_path, height=600))
      print("\n")
